# %%
import pandas as pd

# %%
df=pd.read_csv('data/survey_results_public.csv',index_col='Respondent')

# %%
students={
    "name":["ram","laxman","bharat"],
    "age":["28","25","22"],
    "roles":["leader","follower","ruler"]
}

# %%
students_df=pd.DataFrame(students)

# %%
students_df

# %%
students_df['age']

# %%
students_df.set_index('age')

# %%
students_df.set_index('age', inplace=True) # this will make age as index for subsequent calls

# %%
students_df.loc[0,'name']

# %%
students_df.reset_index(inplace=True)

# %%
df

# %%
df.loc[1]

# %%
df.sort_index()

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df['Country']=='Thailand'
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: Country, Length: 88883, dtype: bool

# %%
filt = df['Country']=='Thailand'

# %%
df[filt]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 3           I am not primarily a developer, but I write co...      Yes
# 255                    I am a student who is learning to code      Yes
# 736                            I am a developer by profession      Yes
# 1602                           I am a developer by profession      Yes
# 1660                   I am a student who is learning to code      Yes
# ...                                                       ...      ...
# 53984                                                     NaN      Yes
# 68027                                                     NaN      Yes
# 68401                                                     NaN      Yes
# 75530                                                     NaN      Yes
# 83612                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df[df['Country']=='India'] #filtering directly
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
df.loc[filt] #using loc does the same function
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 3           I am not primarily a developer, but I write co...      Yes
# 255                    I am a student who is learning to code      Yes
# 736                            I am a developer by profession      Yes
# 1602                           I am a developer by profession      Yes
# 1660                   I am a student who is learning to code      Yes
# ...                                                       ...      ...
# 53984                                                     NaN      Yes
# 68027                                                     NaN      Yes
# 68401                                                     NaN      Yes
# 75530                                                     NaN      Yes
# 83612                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.loc[filt,'Hobbyist']
# Out:
# Respondent
# 3        Yes
# 255      Yes
# 736      Yes
# 1602     Yes
# 1660     Yes
#         ...
# 53984    Yes
# 68027    Yes
# 68401    Yes
# 75530    Yes
# 83612    Yes
# Name: Hobbyist, Length: 214, dtype: object

# %%
india_filt=(df['Country']=='India') & (df['Hobbyist']=='Yes')

# %%
(df['Country']=='India') | (df['Country']=='Thailand') #parantheses are important in conditional operations
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: Country, Length: 88883, dtype: bool

# %%
df[india_filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
df[~india_filt] #not
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df['CompTotal']>1000
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4         True
# 5        False
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: CompTotal, Length: 88883, dtype: bool

# %%
countries=['United States', 'India', 'Canada']

# %%
filt=df['Country'].isin(countries)

# %%
df[filt]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 4                              I am a developer by profession       No
# 6           I am not primarily a developer, but I write co...      Yes
# 8                                 I code primarily as a hobby      Yes
# 10                             I am a developer by profession      Yes
# 12                     I am a student who is learning to code       No
# ...                                                       ...      ...
# 85182                                                     NaN       No
# 85642                                                     NaN       No
# 86012                                                     NaN      Yes
# 88282                                                     NaN      Yes
# 88377                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
filt=df['LanguageWorkedWith'].str.contains('Python',na=False) # string contains

# %%
df[filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
# ...                                            ...      ...
# 84539                                          NaN      Yes
# 85738                                          NaN      Yes
# 86566                                          NaN      Yes
# 87739                                          NaN      Yes
# 88212                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...
