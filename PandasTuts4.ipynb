# %%
import pandas as pd

# %%
people={"first":["dwarak","ram","nag"],
       "last":["nath","nath","laxmi"],
       "age":["27","45","40"]}

# %%
df=pd.DataFrame(people)

# %%
df['full_name']=df['first']+' '+df['last']

# %%
df
# Out:
#     first   last age    full_name
# 0  dwarak   nath  27  dwarak nath
# 1     ram   nath  45     ram nath
# 2     nag  laxmi  40    nag laxmi

# %%
df.drop(columns=['full_name'],inplace=True)

# %%
df
# Out:
#     first   last age
# 0  dwarak   nath  27
# 1     ram   nath  45
# 2     nag  laxmi  40

# %%
df['full_name']=df['first']+' '+df['last']

# %%
df['full_name'].str.split(' ')
# Out:
# 0    [dwarak, nath]
# 1       [ram, nath]
# 2      [nag, laxmi]
# Name: full_name, dtype: object

# %%
df['full_name'].str.split(' ',expand=True)
# Out:
#         0      1
# 0  dwarak   nath
# 1     ram   nath
# 2     nag  laxmi

# %%
df[['f_name','l_name']]=df['full_name'].str.split(' ',expand=True)

# %%
df
# Out:
#     first   last age    full_name  f_name l_name
# 0  dwarak   nath  27  dwarak nath  dwarak   nath
# 1     ram   nath  45     ram nath     ram   nath
# 2     nag  laxmi  40    nag laxmi     nag  laxmi

# %%
df.append({'first':'swathi'},ignore_index=True)
# Out:
#     first   last  age    full_name  f_name l_name
# 0  dwarak   nath   27  dwarak nath  dwarak   nath
# 1     ram   nath   45     ram nath     ram   nath
# 2     nag  laxmi   40    nag laxmi     nag  laxmi
# 3  swathi    NaN  NaN          NaN     NaN    NaN

# %%
people={"first":["dwarak","ram","nag"],
       "last":["nath","nath","laxmi"],
       "age":["27","45","40"]}

# %%
df1=pd.DataFrame(people)

# %%
people={"first":["swathi","swapna"],
       "last":["nath","nath"],
       "age":["27","45"]}

# %%
df2=pd.DataFrame(people)

# %%
df1.append(df2,ignore_index=True)
# Out:
#     first   last age
# 0  dwarak   nath  27
# 1     ram   nath  45
# 2     nag  laxmi  40
# 3  swathi   nath  27
# 4  swapna   nath  45

# %%
df3=df1.append(df2,ignore_index=True)

# %%
df3.drop(index=[3,4]) # use inplace true if to make permanent
# Out:
#     first   last age
# 0  dwarak   nath  27
# 1     ram   nath  45
# 2     nag  laxmi  40

# %%
df3.sort_values(by='age')
# Out:
#     first   last age
# 0  dwarak   nath  27
# 3  swathi   nath  27
# 2     nag  laxmi  40
# 1     ram   nath  45
# 4  swapna   nath  45

# %%
df3.sort_values(by='age',ascending=False)
# Out:
#     first   last age
# 1     ram   nath  45
# 4  swapna   nath  45
# 2     nag  laxmi  40
# 0  dwarak   nath  27
# 3  swathi   nath  27

# %%
df3.sort_values(by=['age','first'],ascending=False)
# Out:
#     first   last age
# 4  swapna   nath  45
# 1     ram   nath  45
# 2     nag  laxmi  40
# 3  swathi   nath  27
# 0  dwarak   nath  27

# %%
df3.sort_values(by=['age','first'],ascending=[False, True], inplace=True)

# %%
df3
# Out:
#     first   last age
# 1     ram   nath  45
# 4  swapna   nath  45
# 2     nag  laxmi  40
# 0  dwarak   nath  27
# 3  swathi   nath  27

# %%
df3.sort_index()
# Out:
#     first   last age
# 0  dwarak   nath  27
# 1     ram   nath  45
# 2     nag  laxmi  40
# 3  swathi   nath  27
# 4  swapna   nath  45

# %%
df=pd.read_csv('data/survey_results_public.csv')

# %%
df.sort_values('Country')
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 39018       39258  I am a developer by profession      Yes
# 62723       63129  I am a developer by profession      Yes
# 85185       85715  I am a developer by profession       No
# 50437       50767  I am a developer by profession       No
# 88340        2782                             NaN      Yes
# ...           ...                             ...      ...
# 88873       88062                             NaN       No
# 88874       88076                             NaN       No
# 88879       88601                             NaN       No
# 88880       88802                             NaN       No
# 88881       88816                             NaN       No
#
#                    OpenSourcer  \
# 39018  Less than once per year
# 62723                    Never
# 85185  Less than once per year
# 50437  Less than once per year
# 88340  Less than once per year
# ...                        ...
# ...

# %%
df['ConvertedComp'].nlargest(5) #nsmallest
# Out:
# 57     2000000.0
# 101    2000000.0
# 164    2000000.0
# 434    2000000.0
# 450    2000000.0
# Name: ConvertedComp, dtype: float64
